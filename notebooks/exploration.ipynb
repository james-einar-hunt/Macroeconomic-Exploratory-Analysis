# %% [markdown]
# # Macroeconomic Exploratory Analysis
#
# This notebook is intended to run from top to bottom without manual intervention.
#
# Author: James Hunt
# Kernel: Python 3.13.5
# Last updated: 2026-06-06
#
# ## 1. Objective
#
# Investigate the relationship between:
# - CPI inflation
# - Unemployment rate
# - Effective Federal Funds Rate
#
# using FRED data from 2000-present.
#
# ## 2. Questions
#
# 1. {Insert questions here}

# %% [markdown]
# ## 3. Environment Setup

# %%
# Standard library
import os

# Third-party packages
import matplotlib.pyplot as plt
import pandas as pd

# Local imports
from fred_tools import acquisition

# %% [markdown]
# ## 4. Configuration

# %%
# Time series dates
START_DATE = "2001-01-01"
END_DATE = None

# %% [markdown]
# ## 5. Data Acquisition

# %%
unrate = acquisition.get_series(
    "UNRATE",
    start_date=START_DATE
)

# %% [markdown]
# ## 6. Data Inspection

# %% [markdown]
# ## 7. Data Cleaning and Transformation

# %% [markdown]
# ## 8. Analysis

# %%
# Plot unemployment rate
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(unrate.index, unrate.values, linewidth=1.5)

ax.set_title("Unemployment Rate (UNRATE)")
ax.set_xlabel("Date")
ax.set_ylabel("Rate (%)")

ax.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Results

# %% [markdown]
# ## 10. Discussion
#
# ### Interpretation
#
# ### Follow-up Work
